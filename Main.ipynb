# %%
import pandas as pd

# %%
movies=pd.read_csv('E:\movie_recommender_system-main\wsmetadata.csv',encoding='latin-1')

# %%
movies.head(10)
# Out:
#                         title  Year Released Content Rating  IMDB Rating  \
# 0                Breaking Bad           2008            18+          9.5
# 1             Game of Thrones           2011            18+          9.3
# 2              Rick and Morty           2013            18+          9.2
# 3             Stranger Things           2016            16+          8.8
# 4                    The Boys           2019            18+          8.7
# 5                        Dark           2017            16+          8.8
# 6                   Chernobyl           2019            18+          9.4
# 7                    Sherlock           2010            16+          9.1
# 8                       Fargo           2014            18+          8.9
# 9  Avatar: The Last Airbender           2005             7+          9.2
#
#    R Rating                         Genre  \
# 0       100                   Crime,Drama
# 1        99      Action & Adventure,Drama
# ...

# %%
movies.describe()
# Out:
#        Year Released  IMDB Rating     R Rating  Unnamed: 9           id
# count    2004.000000  2003.000000  2004.000000         0.0  2004.000000
# mean     2009.678144     7.763055    72.413673         NaN  1030.544910
# std        11.588195     0.670860     7.111271         NaN   604.741683
# min      1940.000000     3.600000    64.000000         NaN     1.000000
# 25%      2006.000000     7.350000    67.000000         NaN   504.750000
# 50%      2014.000000     7.800000    70.500000         NaN  1020.500000
# 75%      2017.000000     8.200000    77.000000         NaN  1552.250000
# max      2020.000000     9.700000   100.000000         NaN  2087.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2004 entries, 0 to 2003
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               2004 non-null   object
#  1   Year Released       2004 non-null   int64
#  2   Content Rating      1923 non-null   object
#  3   IMDB Rating         2003 non-null   float64
#  4   R Rating            2004 non-null   int64
#  5   Genre               2004 non-null   object
#  6   Description         2004 non-null   object
#  7   No of Seasons       2004 non-null   object
#  8   Streaming Platform  1835 non-null   object
#  9   Unnamed: 9          0 non-null      float64
#  10  id                  2004 non-null   int64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 172.3+ KB

# %%
movies.isnull().sum()
# Out:
# title                    0
# Year Released            0
# Content Rating          81
# IMDB Rating              1
# R Rating                 0
# Genre                    0
# Description              0
# No of Seasons            0
# Streaming Platform     169
# Unnamed: 9            2004
# id                       0
# dtype: int64

# %% [markdown]
# Feature Selection Part

# %%
movies.columns
# Out:
# Index(['title', 'Year Released', 'Content Rating', 'IMDB Rating', 'R Rating',
#        'Genre', 'Description', 'No of Seasons', 'Streaming Platform',
#        'Unnamed: 9', 'id'],
#       dtype='object')

# %%
movies=movies[['id', 'title', 'Description', 'Genre']]

# %%
movies
# Out:
#         id                                              title  \
# 0        1                                       Breaking Bad
# 1        2                                    Game of Thrones
# 2        3                                     Rick and Morty
# 3        4                                    Stranger Things
# 4        5                                           The Boys
# ...    ...                                                ...
# 1999  2083  Atlanta's Missing and Murdered: The Lost Children
# 2000  2084                                      The InBetween
# 2001  2085                                          Sick Note
# 2002  2086                                    Snoopy In Space
# 2003  2087                                   Naked and Afraid
#
#                                             Description  \
# 0     When Walter White, a New Mexico chemistry teac...
# 1     Seven noble families fight for control of the ...
# ...

# %%
movies['tags'] = movies['Description']+movies['Genre']

# %%
movies
# Out:
#       series Id                                       Series Title  \
# 0             1                                       Breaking Bad
# 1             2                                    Game of Thrones
# 2             3                                     Rick and Morty
# 3             4                                    Stranger Things
# 4             5                                           The Boys
# ...         ...                                                ...
# 1999       2083  Atlanta's Missing and Murdered: The Lost Children
# 2000       2084                                      The InBetween
# 2001       2085                                          Sick Note
# 2002       2086                                    Snoopy In Space
# 2003       2087                                   Naked and Afraid
#
#                                             Description  \
# 0     When Walter White, a New Mexico chemistry teac...
# ...

# %%
new_data  = movies.drop(columns=['Description', 'Genre'])

# %%
new_data
# Out:
#         id                                              title  \
# 0        1                                       Breaking Bad
# 1        2                                    Game of Thrones
# 2        3                                     Rick and Morty
# 3        4                                    Stranger Things
# 4        5                                           The Boys
# ...    ...                                                ...
# 1999  2083  Atlanta's Missing and Murdered: The Lost Children
# 2000  2084                                      The InBetween
# 2001  2085                                          Sick Note
# 2002  2086                                    Snoopy In Space
# 2003  2087                                   Naked and Afraid
#
#                                                    tags
# 0     When Walter White, a New Mexico chemistry teac...
# 1     Seven noble families fight for control of the ...
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer(max_features=10000, stop_words='english')

# %%
cv
# Out:
# CountVectorizer(max_features=10000, stop_words='english')

# %%
vector=cv.fit_transform(new_data['tags'].values.astype('U')).toarray()

# %%
vector.shape
# Out:
# (2004, 10000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.40838256, 0.22862328, ..., 0.2820441 , 0.20006924,
#         0.22509257],
#        [0.40838256, 1.        , 0.29376299, ..., 0.20737877, 0.24585378,
#         0.34176828],
#        [0.22862328, 0.29376299, 1.        , ..., 0.27743548, 0.37276253,
#         0.36451826],
#        ...,
#        [0.2820441 , 0.20737877, 0.27743548, ..., 1.        , 0.24678382,
#         0.30362885],
#        [0.20006924, 0.24585378, 0.37276253, ..., 0.24678382, 1.        ,
#         0.33113309],
#        [0.22509257, 0.34176828, 0.36451826, ..., 0.30362885, 0.33113309,
#         1.        ]])

# %%
new_data[new_data['title']=="Breaking Bad"].index[0]
# Out:
# 0

# %%
new_data
# Out:
#         id                                              title  \
# 0        1                                       Breaking Bad
# 1        2                                    Game of Thrones
# 2        3                                     Rick and Morty
# 3        4                                    Stranger Things
# 4        5                                           The Boys
# ...    ...                                                ...
# 1999  2083  Atlanta's Missing and Murdered: The Lost Children
# 2000  2084                                      The InBetween
# 2001  2085                                          Sick Note
# 2002  2086                                    Snoopy In Space
# 2003  2087                                   Naked and Afraid
#
#                                                    tags
# 0     When Walter White, a New Mexico chemistry teac...
# 1     Seven noble families fight for control of the ...
# ...

# %%
distance = sorted(list(enumerate(similarity[2])), reverse=True, key=lambda vector:vector[1])
for i in distance[0:5]:
    print(new_data.iloc[i[0]].title)
# Out:
# Rick and Morty
# F is for Family
# South Park
# One Day at a Time
# My Hero Academia

# %%
def recommand(movies):
    index=new_data[new_data['title']==movies].index[0]
    distance = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda vector:vector[1])
    for i in distance[0:5]:
        print(new_data.iloc[i[0].title])

# %%
recommand("Breaking Bad")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22636/746633181.py in <module>
# ----> 1 recommand("Breaking Bad")
#
# ~\AppData\Local\Temp/ipykernel_22636/3442398821.py in recommand(movies)
#       3     distance = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda vector:vector[1])
#       4     for i in distance[0:5]:
# ----> 5         print(new_data.iloc[i[0].title])
#
# AttributeError: 'int' object has no attribute 'title'

# %%
import pickle

# %%
pickle.dump(new_data, open('series_list.pkl', 'wb'))

# %%
pickle.dump(similarity, open('similarity1.pkl', 'wb'))

# %%
pickle.load(open('series_list.pkl', 'rb'))
# Out:
#         id                                              title  \
# 0        1                                       Breaking Bad
# 1        2                                    Game of Thrones
# 2        3                                     Rick and Morty
# 3        4                                    Stranger Things
# 4        5                                           The Boys
# ...    ...                                                ...
# 1999  2083  Atlanta's Missing and Murdered: The Lost Children
# 2000  2084                                      The InBetween
# 2001  2085                                          Sick Note
# 2002  2086                                    Snoopy In Space
# 2003  2087                                   Naked and Afraid
#
#                                                    tags
# 0     When Walter White, a New Mexico chemistry teac...
# 1     Seven noble families fight for control of the ...
# ...
